# %%
# Dependencies
from bs4 import BeautifulSoup as bs
from splinter import Browser
import time 
import pandas as pd
import requests

# %%
executable_path = {'executable_path': 'C:/Users/briv1/OneDrive/Desktop/Data_Bootcamp/chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
mars_article_url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
browser.visit(mars_article_url)
time.sleep(5)

# %%
html = browser.html
soup = bs(html, 'html.parser')

# for li in soup:

article_title_list = soup.select('li.slide .content_title')
article_content_list = soup.select('li.slide .article_teaser_body')
print('----------------')
print(article_title_list)
print('----------------')
print('----------------')
print(article_content_list)
# Out:
# ----------------
# [<div class="content_title">
# 										  Bahram Vallis
# 										</div>, <div class="content_title">
# 										  North Pole
# 										</div>, <div class="content_title">
# 										  Seismic Waves Inside Mars (Artist's Concept)
# 										</div>, <div class="content_title">
# 										  North Polar Layers
# 										</div>, <div class="content_title">
# 										  Olympia Undae
# 										</div>, <div class="content_title">
# 										  On the Edge
# 										</div>, <div class="content_title">
# 										  Hephaestus Fossae
# 										</div>, <div class="content_title">
# 										  Where the Wind Blows
# 										</div>, <div class="content_title">
# 										  Arena Colles
# 										</div>, <div class="content_title">
# 										  HiRISE Spots Curiosity at Woodland Bay
# 										</div>, <div class="content_title">
# 										  Ascraeus Mons
# 										</div>, <div class="content_title">
# 										  Scamander Vallis
# ...

# %%
for title in article_title_list:
    article_title = (title).text
    print('----------------')
    print(article_title)
# Out:
# ----------------
#
# 										  Bahram Vallis
#
# ----------------
#
# 										  North Pole
#
# ----------------
#
# 										  Seismic Waves Inside Mars (Artist's Concept)
#
# ----------------
#
# 										  North Polar Layers
#
# ----------------
#
# 										  Olympia Undae
#
# ----------------
#
# 										  On the Edge
#
# ----------------
#
# 										  Hephaestus Fossae
#
# ----------------
#
# 										  Where the Wind Blows
#
# ----------------
#
# 										  Arena Colles
#
# ----------------
#
# 										  HiRISE Spots Curiosity at Woodland Bay
#
# ----------------
#
# 										  Ascraeus Mons
#
# ----------------
#
# 										  Scamander Vallis
#
# ----------------
#
# 										  Wind Action
#
# ----------------
#
# 										  Radial Ejecta
#
# ----------------
#
# 										  Cerberus Fossae
#
# ----------------
#
# 										  What Could It Be?
#
# ----------------
#
# 										  Labeatis Fossae
#
# ----------------
#
# 										  Tooting Crater
#
# ...

# %%
for content in article_content_list:
    article_content = (content).text
    images = soup.findAll('img')
#     print('----------------')
#     print(article_content)
#     print('----------------')
#     print(images)
    
len(images)
# Out:
# 87

# %%
mars_images_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(mars_images_url)
time.sleep(3)
browser.click_link_by_partial_text('FULL IMAGE')

# %%
images = soup.findAll('img')
# print('----------------')
# print(images)
len(images)
# Out:
# 87

# %%
for image in images:
    image_file = (image).span

print(image_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-46540a7246f0> in <module>
#       2     image_file = (image).span
#       3
# ----> 4 print(image_file)
#
# NameError: name 'image_file' is not defined
